# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("darkgrid")
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('data.csv', low_memory=False)

# %%
data.head()
# Out:
#    building_id  meter           timestamp  meter_reading
# 0            0      0  2016-01-01 0:00:00            0.0
# 1            1      0  2016-01-01 0:00:00            0.0
# 2            2      0  2016-01-01 0:00:00            0.0
# 3            3      0  2016-01-01 0:00:00            0.0
# 4            4      0  2016-01-01 0:00:00            0.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498513 entries, 0 to 498512
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   building_id    498513 non-null  int64
#  1   meter          498513 non-null  int64
#  2   timestamp      498513 non-null  object
#  3   meter_reading  498513 non-null  float64
# dtypes: float64(1), int64(2), object(1)
# memory usage: 15.2+ MB

# %%
data['timestamp'] = pd.to_datetime(data['timestamp'], utc=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498513 entries, 0 to 498512
# Data columns (total 4 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   building_id    498513 non-null  int64
#  1   meter          498513 non-null  int64
#  2   timestamp      498513 non-null  datetime64[ns, UTC]
#  3   meter_reading  498513 non-null  float64
# dtypes: datetime64[ns, UTC](1), float64(1), int64(2)
# memory usage: 15.2 MB

# %%
data.head()
# Out:
#    building_id  meter                 timestamp  meter_reading
# 0            0      0 2016-01-01 00:00:00+00:00            0.0
# 1            1      0 2016-01-01 00:00:00+00:00            0.0
# 2            2      0 2016-01-01 00:00:00+00:00            0.0
# 3            3      0 2016-01-01 00:00:00+00:00            0.0
# 4            4      0 2016-01-01 00:00:00+00:00            0.0

# %%
# analysis for meter type 0

data_0 = data[data['meter']==0]

# %%
data_0.reset_index(inplace=True)

# %%
data_0.iloc[:,3][0].day
# Out:
# 1

# %%
data_0['day'] = [i.day for i in data_0.iloc[:,3]]

# %%
data_0.head()
# Out:
#    index  building_id  meter                 timestamp  meter_reading  day
# 0      0            0      0 2016-01-01 00:00:00+00:00            0.0    1
# 1      1            1      0 2016-01-01 00:00:00+00:00            0.0    1
# 2      2            2      0 2016-01-01 00:00:00+00:00            0.0    1
# 3      3            3      0 2016-01-01 00:00:00+00:00            0.0    1
# 4      4            4      0 2016-01-01 00:00:00+00:00            0.0    1

# %%
plt.rcParams['figure.figsize'] = (18,8)

# %%
sns.lineplot(data_0.timestamp, y = data_0.meter_reading, hue = data_0.day)
# Out:
# <AxesSubplot: xlabel='timestamp', ylabel='meter_reading'>

# %%
#time series for meter type 1

data_1 = data[data['meter']==1]
data_1.reset_index(inplace=True)
data_1['day'] = [i.day for i in data_1.iloc[:,3]]
sns.lineplot(data_1.timestamp, y = data_1.meter_reading, hue = data_1.day)
# Out:
# <AxesSubplot: xlabel='timestamp', ylabel='meter_reading'>

# %%
#time series for meter type 2

data_2 = data[data['meter']==2]
data_2.reset_index(inplace=True)
data_2['day'] = [i.day for i in data_2.iloc[:,3]]
sns.lineplot(data_2.timestamp, y = data_2.meter_reading, hue = data_2.day)
# Out:
# <AxesSubplot: xlabel='timestamp', ylabel='meter_reading'>

# %%
#time series for meter type 3

data_3 = data[data['meter']==3]
data_3.reset_index(inplace=True)
data_3['day'] = [i.day for i in data_3.iloc[:,3]]
sns.lineplot(data_3.timestamp, y = data_3.meter_reading, hue = data_3.day)
# Out:
# <AxesSubplot: xlabel='timestamp', ylabel='meter_reading'>

# %%
data1 = data[['timestamp','building_id', 'meter', 'meter_reading']]

# %%
data1.set_index('timestamp', inplace=True)

# %%
data1.head()
# Out:
#                            building_id  meter  meter_reading
# timestamp
# 2016-01-01 00:00:00+00:00            0      0            0.0
# 2016-01-01 00:00:00+00:00            1      0            0.0
# 2016-01-01 00:00:00+00:00            2      0            0.0
# 2016-01-01 00:00:00+00:00            3      0            0.0
# 2016-01-01 00:00:00+00:00            4      0            0.0

# %%
data_t0 = data1[data1['meter_reading']==0]

# %%
data_t0.shape
# Out:
# (61034, 3)

# %%
data_t0.head()
# Out:
#                            building_id  meter  meter_reading
# timestamp
# 2016-01-01 00:00:00+00:00            0      0            0.0
# 2016-01-01 00:00:00+00:00            1      0            0.0
# 2016-01-01 00:00:00+00:00            2      0            0.0
# 2016-01-01 00:00:00+00:00            3      0            0.0
# 2016-01-01 00:00:00+00:00            4      0            0.0

# %%
data.timestamp[0].hour
# Out:
# 0

# %%
data['hour'] = [i.hour for i in data.timestamp]

# %%
data
# Out:
#         building_id  meter                 timestamp  meter_reading  hour
# 0                 0      0 2016-01-01 00:00:00+00:00          0.000     0
# 1                 1      0 2016-01-01 00:00:00+00:00          0.000     0
# 2                 2      0 2016-01-01 00:00:00+00:00          0.000     0
# 3                 3      0 2016-01-01 00:00:00+00:00          0.000     0
# 4                 4      0 2016-01-01 00:00:00+00:00          0.000     0
# ...             ...    ...                       ...            ...   ...
# 498508         1444      0 2016-01-10 00:00:00+00:00          6.100     0
# 498509         1445      0 2016-01-10 00:00:00+00:00          4.700     0
# 498510         1446      0 2016-01-10 00:00:00+00:00          0.000     0
# 498511         1447      0 2016-01-10 00:00:00+00:00        167.000     0
# 498512         1448      0 2016-01-10 00:00:00+00:00          2.675     0
#
# [498513 rows x 5 columns]

# %%
data.groupby(['hour', 'building_id', 'meter']).sum()
# Out:
#                         meter_reading
# hour building_id meter
# 0    0           0              0.000
#      1           0              0.000
#      2           0              0.000
#      3           0              0.000
#      4           0              0.000
# ...                               ...
# 23   1444        0             70.925
#      1445        0             46.575
#      1446        0             21.725
#      1447        0           1423.825
#      1448        0             27.250
#
# [55396 rows x 1 columns]
